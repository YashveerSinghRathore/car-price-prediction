# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/used car pp.csv")

# %%
df
# Out:
#          brand                            model  model_year  car_age  \
# 0         Ford  Utility Police Interceptor Base        2013       11
# 1      Hyundai                     Palisade SEL        2021        3
# 2        Lexus                    RX 350 RX 350        2022        2
# 3     INFINITI                 Q50 Hybrid Sport        2015        9
# 4         Audi        Q3 45 S line Premium Plus        2021        3
# ...        ...                              ...         ...      ...
# 3959   Bentley             Continental GT Speed        2023        1
# 3960      Audi             S4 3.0T Premium Plus        2022        2
# 3961   Porsche                           Taycan        2022        2
# 3962      Ford                     F-150 Raptor        2020        4
# 3963       BMW                     X3 xDrive30i        2020        4
#
#      milage (Miles)      fuel_type  \
# 0            51,000  E85 Flex Fuel
# 1            34,742       Gasoline
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create LabelEncoder instances
le_brand = LabelEncoder()
le_model = LabelEncoder()
le_fuel_type = LabelEncoder()
le_transmission = LabelEncoder()

# Encode 'brand'
df['brand_encoded'] = le_brand.fit_transform(df['brand'])

# Encode 'model'
df['model_encoded'] = le_model.fit_transform(df['model'])

# Encode 'fuel_type'
df['fuel_type_encoded'] = le_fuel_type.fit_transform(df['fuel_type'])

# Encode 'transmission'
df['transmission_encoded'] = le_transmission.fit_transform(df['transmission'])


# Display the first few rows
df.head()
# Out:
#       brand                            model  model_year  car_age  \
# 0      Ford  Utility Police Interceptor Base        2013       11
# 1   Hyundai                     Palisade SEL        2021        3
# 2     Lexus                    RX 350 RX 350        2022        2
# 3  INFINITI                 Q50 Hybrid Sport        2015        9
# 4      Audi        Q3 45 S line Premium Plus        2021        3
#
#   milage (Miles)      fuel_type  \
# 0         51,000  E85 Flex Fuel
# 1         34,742       Gasoline
# 2         22,372       Gasoline
# 3         88,900         Hybrid
# 4          9,835       Gasoline
#
#                                               engine transmission  \
# 0  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...    Automatic
# 1                               3.8L V6 24V GDI DOHC    Automatic
# 2                                     3.5 Liter DOHC    Automatic
# 3  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...    Automatic
# ...

# %%
df=df.drop(["brand","model","fuel_type","transmission","engine","ext_col","int_col", "accident", "clean_title"],axis=1)
# Out:
#       model_year  car_age milage (Miles)  price in (USD)  brand_encoded  \
# 0           2013       11         51,000           10300             14
# 1           2021        3         34,742           38005             19
# 2           2022        2         22,372           54598             27
# 3           2015        9         88,900           15500             20
# 4           2021        3          9,835           34999              3
# ...          ...      ...            ...             ...            ...
# 3959        2023        1            714          349950              5
# 3960        2022        2         10,900           53900              3
# 3961        2022        2          2,116           90998             43
# 3962        2020        4         33,000           62999             14
# 3963        2020        4         43,000           40000              4
#
#       model_encoded  fuel_type_encoded  transmission_encoded
# ...

# %%
df=df.drop(['model_year'],axis=1)

# %%
x=df.drop("price in (USD)",axis=1)
y=df["price in (USD)"]

# %%
x=pd.get_dummies(x)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# Initialize the model
model = RandomForestRegressor(n_estimators=100, random_state=42)

# Train the model
model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Predict on the test set
y_pred = model.predict(x_test)

# Calculate Mean Squared Error and Root Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# Calculate R^2 Score
r2 = r2_score(y_test, y_pred)

print(f"RMSE: {rmse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# RMSE: 57315.34
# R^2 Score: 0.41

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel('Actual Prices')
plt.ylabel('Predicted Prices')
plt.title('Actual vs. Predicted Car Prices')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.show()

# %%
import pickle

# Save the model
with open('car_price_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# Save the label encoders
with open('le_brand.pkl', 'wb') as file:
    pickle.dump(le_brand, file)

with open('le_model.pkl', 'wb') as file:
    pickle.dump(le_model, file)

with open('le_fuel_type.pkl', 'wb') as file:
    pickle.dump(le_fuel_type, file)

with open('le_transmission.pkl', 'wb') as file:
    pickle.dump(le_transmission, file)

# %%
from google.colab import files

# Download the model file
files.download('car_price_model.pkl')

# Download the label encoder files
files.download('le_brand.pkl')
files.download('le_model.pkl')
files.download('le_fuel_type.pkl')
files.download('le_transmission.pkl')
